# %% [markdown]
# # Looking at Clear Creek Stream Guage Data during spring runoff season
# - <https://waterservices.usgs.gov/rest/IV-Service.html#URLFormat>
# - compare with temperature
# - is time in UTC?
# - get stream flow also, how is it related to height?
# - look at stations upstream, they should peak earlier as we get closer to source?
# - compare time lag with distance to source (cont.divide?) and compute average speed, compare to streamflow measured

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# base_url = 'http://waterservices.usgs.gov/nwis/iv/?<arguments>'
base_url = 'http://waterservices.usgs.gov/nwis/iv/?'

# %%
# parameters for API request
site = '06719505' # site number for Clear Creek in Golden
format_out = 'json'
indent = 'on' # indent json output for easier viewiing
period = 'P50D' # last 7 days
#&variable=00060	//	discharge,	cubic feet per second

# %%
request_url = base_url + 'site=' + site + '&format=' + format_out + '&indent=' + indent + '&period=' + period
request_url
# Out:
# 'http://waterservices.usgs.gov/nwis/iv/?site=06719505&format=json&indent=on&period=P50D'

# %%
resp = requests.get(request_url)

# %%
resp.json()
# Out:
# {'declaredType': 'org.cuahsi.waterml.TimeSeriesResponseType',
#  'globalScope': True,
#  'name': 'ns1:timeSeriesResponseType',
#  'nil': False,
#  'scope': 'javax.xml.bind.JAXBElement$GlobalScope',
#  'typeSubstituted': False,
#  'value': {'queryInfo': {'criteria': {'locationParam': '[ALL:06719505]',
#     'parameter': [],
#     'variableParam': 'ALL'},
#    'note': [{'title': 'filter:sites', 'value': '[ALL:06719505]'},
#     {'title': 'filter:timeRange',
#      'value': '[mode=PERIOD, period=P50D, modifiedSince=null]'},
#     {'title': 'filter:methodId', 'value': 'methodIds=[ALL]'},
#     {'title': 'requestDT', 'value': '2017-07-01T18:14:49.902Z'},
#     {'title': 'requestId', 'value': '2bf3add1-5e89-11e7-ac07-6cae8b6642f6'},
#     {'title': 'disclaimer',
#      'value': 'Provisional data are subject to revision. Go to http://waterdata.usgs.gov/nwis/help/?provisional for more information.'},
#     {'title': 'server', 'value': 'caas01'}],
# ...

# %%
js = resp.json()

# %%
# length of this list will be # of variables
len(js['value']['timeSeries'])
# Out:
# 2

# %%
js['value']['timeSeries'][0]['variable']['variableName']
# Out:
# 'Streamflow, ft&#179;/s'

# %%
js['value']['timeSeries'][1]['variable']['variableName']
# Out:
# 'Gage height, ft'

# %%
js.keys()
# Out:
# dict_keys(['name', 'declaredType', 'scope', 'value', 'nil', 'globalScope', 'typeSubstituted'])

# %%
js['value'].keys()
# Out:
# dict_keys(['queryInfo', 'timeSeries'])

# %%
# list of dicts
type(js['value']['timeSeries'])
# Out:
# list

# %%
type(js['value']['timeSeries'][1])
# Out:
# dict

# %%
js['value']['timeSeries'][1].keys()
# Out:
# dict_keys(['sourceInfo', 'variable', 'values', 'name'])

# %%
type(js['value']['timeSeries'][1]['values'])
# Out:
# list

# %%
js['value']['timeSeries'][1]['values'][0]['value']
# Out:
# [{'dateTime': '2017-05-12T12:15:00.000-06:00',
#   'qualifiers': ['P'],
#   'value': '4.59'},
#  {'dateTime': '2017-05-12T12:30:00.000-06:00',
#   'qualifiers': ['P'],
#   'value': '4.60'},
#  {'dateTime': '2017-05-12T12:45:00.000-06:00',
#   'qualifiers': ['P'],
#   'value': '4.59'},
#  {'dateTime': '2017-05-12T13:00:00.000-06:00',
#   'qualifiers': ['P'],
#   'value': '4.60'},
#  {'dateTime': '2017-05-12T13:15:00.000-06:00',
#   'qualifiers': ['P'],
#   'value': '4.59'},
#  {'dateTime': '2017-05-12T13:30:00.000-06:00',
#   'qualifiers': ['P'],
#   'value': '4.60'},
#  {'dateTime': '2017-05-12T13:45:00.000-06:00',
#   'qualifiers': ['P'],
#   'value': '4.59'},
#  {'dateTime': '2017-05-12T14:00:00.000-06:00',
#   'qualifiers': ['P'],
#   'value': '4.60'},
#  {'dateTime': '2017-05-12T14:15:00.000-06:00',
#   'qualifiers': ['P'],
#   'value': '4.59'},
#  {'dateTime': '2017-05-12T14:30:00.000-06:00',
#   'qualifiers': ['P'],
#   'value': '4.58'},
# ...

# %%
len(js['value']['timeSeries'][1]['values'][0]['value'])
# Out:
# 4799

# %%
js['value']['timeSeries'][1]['values'][0]['value'][11]['value']
# Out:
# '4.58'

# %%
js['value']['timeSeries'][1]['values'][0]['value'][11]['dateTime']
# Out:
# '2017-05-12T15:00:00.000-06:00'

# %%
dict2 = js['value']['timeSeries'][1]['values'][0]['value']

# %%
dates = []
vals = []
for row in dict2:
    dates.append(row['dateTime'])
    vals.append(row['value'])
    
dates = pd.to_datetime(dates)

# %%
df = pd.DataFrame({'date':dates,'vals':vals},index=dates)
df.head()
# Out:
#                                    date  vals
# 2017-05-12 18:15:00 2017-05-12 18:15:00  4.59
# 2017-05-12 18:30:00 2017-05-12 18:30:00  4.60
# 2017-05-12 18:45:00 2017-05-12 18:45:00  4.59
# 2017-05-12 19:00:00 2017-05-12 19:00:00  4.60
# 2017-05-12 19:15:00 2017-05-12 19:15:00  4.59

# %%
df['date']=pd.to_datetime(df['date'])
df['vals']=df.vals.astype('float64')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4799 entries, 2017-05-12 18:15:00 to 2017-07-01 17:45:00
# Data columns (total 2 columns):
# date    4799 non-null datetime64[ns]
# vals    4799 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 112.5 KB

# %%
plt.plot(df.date,df.vals)
plt.grid();

# %%
df['hour'] = df.date.dt.hour
df['yday'] = df.date.dt.dayofyear
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4799 entries, 2017-05-12 18:15:00 to 2017-07-01 17:45:00
# Data columns (total 4 columns):
# date    4799 non-null datetime64[ns]
# vals    4799 non-null float64
# hour    4799 non-null int64
# yday    4799 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(2)
# memory usage: 187.5 KB

# %%
plt.scatter(df.hour[100:210],df.vals[100:210])

# %%
plt.plot(df.vals['2017-6-15':'2017-6-16'])
plt.grid();

# %%
dict2[0]
# Out:
# ['P']
